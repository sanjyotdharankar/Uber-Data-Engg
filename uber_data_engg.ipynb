# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import io
# import requests

# %%
# url = 'https://storage.googleapis.com/uber-data-engineering-project/uber_data.csv'
# response = requests.get(url)

# %%
df=pd.read_parquet("/content/drive/MyDrive/yellow_tripdata_2023-01.parquet")
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
#check duplicate
df = df.drop_duplicates().reset_index(drop=True)

# %%
df['trip_id'] = df.index

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# create datetime_dim table

# %%
datetime_dim=df[['tpep_pickup_datetime','tpep_dropoff_datetime']].reset_index(drop=True)

# %%
datetime_dim['pickup_hours']=datetime_dim['tpep_pickup_datetime'].dt.hour

# %%
datetime_dim['pick_hour'] = datetime_dim['tpep_pickup_datetime'].dt.hour
datetime_dim['pick_day'] = datetime_dim['tpep_pickup_datetime'].dt.day
datetime_dim['pick_month'] = datetime_dim['tpep_pickup_datetime'].dt.month
datetime_dim['pick_year'] = datetime_dim['tpep_pickup_datetime'].dt.year
datetime_dim['pick_weekday'] = datetime_dim['tpep_pickup_datetime'].dt.weekday
datetime_dim.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  pickup_hours  pick_hour  \
# 0  2023-01-01 00:32:10   2023-01-01 00:40:36             0          0
# 1  2023-01-01 00:55:08   2023-01-01 01:01:27             0          0
# 2  2023-01-01 00:25:04   2023-01-01 00:37:49             0          0
# 3  2023-01-01 00:03:48   2023-01-01 00:13:25             0          0
# 4  2023-01-01 00:10:29   2023-01-01 00:21:19             0          0
#
#    pick_day  pick_month  pick_year  pick_weekday
# 0         1           1       2023             6
# 1         1           1       2023             6
# 2         1           1       2023             6
# 3         1           1       2023             6
# 4         1           1       2023             6

# %%
#drop column pickup_hours
datetime_dim = datetime_dim.drop(columns=['pickup_hours'])
datetime_dim.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  pick_hour  pick_day  pick_month  \
# 0  2023-01-01 00:32:10   2023-01-01 00:40:36          0         1           1
# 1  2023-01-01 00:55:08   2023-01-01 01:01:27          0         1           1
# 2  2023-01-01 00:25:04   2023-01-01 00:37:49          0         1           1
# 3  2023-01-01 00:03:48   2023-01-01 00:13:25          0         1           1
# 4  2023-01-01 00:10:29   2023-01-01 00:21:19          0         1           1
#
#    pick_year  pick_weekday
# 0       2023             6
# 1       2023             6
# 2       2023             6
# 3       2023             6
# 4       2023             6

# %%
datetime_dim['drop_hour'] = datetime_dim['tpep_dropoff_datetime'].dt.hour
datetime_dim['drop_day'] = datetime_dim['tpep_dropoff_datetime'].dt.day
datetime_dim['drop_month'] = datetime_dim['tpep_dropoff_datetime'].dt.month
datetime_dim['drop_year'] = datetime_dim['tpep_dropoff_datetime'].dt.year
datetime_dim['drop_weekday'] = datetime_dim['tpep_dropoff_datetime'].dt.weekday
datetime_dim.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  pick_hour  pick_day  pick_month  \
# 0  2023-01-01 00:32:10   2023-01-01 00:40:36          0         1           1
# 1  2023-01-01 00:55:08   2023-01-01 01:01:27          0         1           1
# 2  2023-01-01 00:25:04   2023-01-01 00:37:49          0         1           1
# 3  2023-01-01 00:03:48   2023-01-01 00:13:25          0         1           1
# 4  2023-01-01 00:10:29   2023-01-01 00:21:19          0         1           1
#
#    pick_year  pick_weekday  drop_hour  drop_day  drop_month  drop_year  \
# 0       2023             6          0         1           1       2023
# 1       2023             6          1         1           1       2023
# 2       2023             6          0         1           1       2023
# 3       2023             6          0         1           1       2023
# 4       2023             6          0         1           1       2023
#
#    drop_weekday
# 0             6
# 1             6
# 2             6
# ...

# %%
datetime_dim['datetime_id'] = datetime_dim.index
datetime_dim = datetime_dim[['datetime_id', 'tpep_pickup_datetime', 'pick_hour', 'pick_day', 'pick_month', 'pick_year', 'pick_weekday',
                             'tpep_dropoff_datetime', 'drop_hour', 'drop_day', 'drop_month', 'drop_year', 'drop_weekday']]

# %%
datetime_dim.head(2)
# Out:
#    datetime_id tpep_pickup_datetime  pick_hour  pick_day  pick_month  \
# 0            0  2023-01-01 00:32:10          0         1           1
# 1            1  2023-01-01 00:55:08          0         1           1
#
#    pick_year  pick_weekday tpep_dropoff_datetime  drop_hour  drop_day  \
# 0       2023             6   2023-01-01 00:40:36          0         1
# 1       2023             6   2023-01-01 01:01:27          1         1
#
#    drop_month  drop_year  drop_weekday
# 0           1       2023             6
# 1           1       2023             6

# %% [markdown]
# passanger table

# %%
passenger_count_dim = df[['passenger_count']].reset_index(drop=True)
passenger_count_dim['passenger_count_id'] = passenger_count_dim.index
passenger_count_dim = passenger_count_dim[['passenger_count_id','passenger_count']]
passenger_count_dim.head()
# Out:
#    passenger_count_id  passenger_count
# 0                   0              1.0
# 1                   1              1.0
# 2                   2              1.0
# 3                   3              0.0
# 4                   4              1.0

# %% [markdown]
# trip_distance_dim table

# %%
trip_distance_dim = df[['trip_distance']].reset_index(drop=True)
trip_distance_dim['trip_distance_id'] = trip_distance_dim.index
trip_distance_dim = trip_distance_dim[['trip_distance_id','trip_distance']]
trip_distance_dim.head()
# Out:
#    trip_distance_id  trip_distance
# 0                 0           0.97
# 1                 1           1.10
# 2                 2           2.51
# 3                 3           1.90
# 4                 4           1.43

# %% [markdown]
# Rate_code_dim table

# %%
rate_code_type = {
    1:"Standard rate",
    2:"JFK",
    3:"Newark",
    4:"Nassau or Westchester",
    5:"Negotiated fare",
    6:"Group ride"
}

rate_code_dim = df[['RatecodeID']].reset_index(drop=True)
rate_code_dim.head()
# Out:
#    RatecodeID
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0

# %%
rate_code_dim['rate_code_id'] = rate_code_dim.index
rate_code_dim['rate_code_name']=rate_code_dim['RatecodeID'].map(rate_code_type)
rate_code_dim = rate_code_dim[['rate_code_id','RatecodeID','rate_code_name']]
rate_code_dim[20:30]
# Out:
#     rate_code_id  RatecodeID rate_code_name
# 20            20         1.0  Standard rate
# 21            21         2.0            JFK
# 22            22         1.0  Standard rate
# 23            23         1.0  Standard rate
# 24            24         1.0  Standard rate
# 25            25         1.0  Standard rate
# 26            26         1.0  Standard rate
# 27            27         1.0  Standard rate
# 28            28         1.0  Standard rate
# 29            29         1.0  Standard rate

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee', 'trip_id'],
#       dtype='object')

# %% [markdown]
# pickup_location _dim table

# %%
pickup_loc=df[['PULocationID']].reset_index(drop=True)
pickup_loc['pickup_location_id'] = pickup_loc.index
pickup_loc = pickup_loc[['pickup_location_id','PULocationID']]
pickup_loc.head()
# Out:
#    pickup_location_id  PULocationID
# 0                   0           161
# 1                   1            43
# 2                   2            48
# 3                   3           138
# 4                   4           107

# %% [markdown]
# Drop_loc table

# %%
dropoff_loc=df[['DOLocationID']].reset_index(drop=True)
dropoff_loc['dropoff_location_id'] = dropoff_loc.index
dropoff_loc = dropoff_loc[['dropoff_location_id','DOLocationID']]
dropoff_loc.head()
# Out:
#    dropoff_location_id  DOLocationID
# 0                    0           141
# 1                    1           237
# 2                    2           238
# 3                    3             7
# 4                    4            79

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %% [markdown]
# Payment type table

# %%
payment_type_name = {
    1:"Credit card",
    2:"Cash",
    3:"No charge",
    4:"Dispute",
    5:"Unknown",
    6:"Voided trip"
}
payment_type =df[['payment_type']].reset_index(drop=True)
payment_type['payment_type_id'] = payment_type.index

payment_type['payment_type_name']=payment_type['payment_type'].map(payment_type_name)
payment_type = payment_type[['payment_type_id','payment_type','payment_type_name']]
payment_type.head()
# Out:
#    payment_type_id  payment_type payment_type_name
# 0                0             2              Cash
# 1                1             1       Credit card
# 2                2             1       Credit card
# 3                3             1       Credit card
# 4                4             1       Credit card

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee', 'trip_id'],
#       dtype='object')

# %% [markdown]
# Fact table

# %%
fact_table = df.merge(passenger_count_dim, left_on='trip_id', right_on='passenger_count_id') \
             .merge(trip_distance_dim, left_on='trip_id', right_on='trip_distance_id') \
             .merge(rate_code_dim, left_on='trip_id', right_on='rate_code_id') \
             .merge(pickup_loc, left_on='trip_id', right_on='pickup_location_id') \
             .merge(dropoff_loc, left_on='trip_id', right_on='dropoff_location_id')\
             .merge(datetime_dim, left_on='trip_id', right_on='datetime_id') \
             .merge(payment_type, left_on='trip_id', right_on='payment_type_id') \
             [['trip_id','VendorID', 'datetime_id', 'passenger_count_id','trip_distance_id', 'rate_code_id',
               'store_and_fwd_flag', 'pickup_location_id','dropoff_location_id', 'payment_type_id',
               'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
               'improvement_surcharge', 'total_amount','congestion_surcharge','airport_fee']]
            # , 'dropoff_loc',
            #    'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
            #    'improvement_surcharge', 'total_amount','congestion_surcharge','airport_fee']]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
fact_table.head()
# Out:
#    trip_id  VendorID  datetime_id  passenger_count_id  trip_distance_id  \
# 0        0         2            0                   0                 0
# 1        1         2            1                   1                 1
# 2        2         2            2                   2                 2
# 3        3         1            3                   3                 3
# 4        4         2            4                   4                 4
#
#    rate_code_id store_and_fwd_flag  pickup_location_id  dropoff_location_id  \
# 0             0                  N                   0                    0
# 1             1                  N                   1                    1
# 2             2                  N                   2                    2
# 3             3                  N                   3                    3
# 4             4                  N                   4                    4
#
# ...

# %%
fact_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3066766 entries, 0 to 3066765
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   trip_id                int64
#  1   VendorID               int64
#  2   datetime_id            int64
#  3   passenger_count_id     int64
#  4   trip_distance_id       int64
#  5   rate_code_id           int64
#  6   store_and_fwd_flag     object
#  7   pickup_location_id     int64
#  8   dropoff_location_id    int64
#  9   payment_type_id        int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
# dtypes: float64(9), int64(9), object(1)
# memory usage: 468.0+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3066766 entries, 0 to 3066765
# Data columns (total 20 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
#  19  trip_id                int64
# ...

# %%
#download the all data
fact_table.to_csv('fact_table.csv', index=False)
datetime_dim.to_csv('datetime_dim.csv', index=False)
passenger_count_dim.to_csv('passenger_count_dim.csv', index=False)
trip_distance_dim.to_csv('trip_distance_dim.csv', index=False)
rate_code_dim.to_csv('rate_code_dim.csv', index=False)
pickup_loc.to_csv('pickup_loc.csv', index=False)
dropoff_loc.to_csv('dropoff_loc.csv', index=False)
payment_type.to_csv('payment_type.csv', index=False)
# return {"datetime_dim":datetime_dim.to_dict(orient="dict"),
#     "passenger_count_dim":passenger_count_dim.to_dict(orient="dict"),
#     "trip_distance_dim":trip_distance_dim.to_dict(orient="dict"),
#     "rate_code_dim":rate_code_dim.to_dict(orient='dict'),
#     "pickup_loc":pickup_loc.to_dict(orient="dict"),
#     "dropoff_loc":dropoff_loc.to_dict(orient="dict"),
#     "payment_type":payment_type.to_dict(orient='dict'),
#     "fact_table":fact_table.to_dict(orient='dict')
    # }

# %%
payment_type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3066766 entries, 0 to 3066765
# Data columns (total 3 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   payment_type_id    int64
#  1   payment_type       int64
#  2   payment_type_name  object
# dtypes: int64(2), object(1)
# memory usage: 70.2+ MB
